# %% [markdown]
# ## データの取り込みと確認

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import japanize_matplotlib
import seaborn as sns
import pandas as pd
import numpy as np
sns.set(font = "IPAexGothic", style = "white") #グラフのプロパティを設定
plt.rcParams["figure.figsize"] = [10, 5] #グラフの大きさを設定
pd.set_option('display.max_columns', 150) #表示する列数の上限を150に設定
pd.set_option('display.max_rows', 50) #表示する行数の上限を50に設定

# %%
# データの取り込み
df_master = pd.read_csv("customer_segment_analysis_data.csv")
df = df_master.copy()
df.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated Profession  Work_Experience  \
# 0  463864    Male          Yes   81        No  Executive              NaN
# 1  465025    Male          Yes   73       Yes  Executive              0.0
# 2  461687  Female          Yes   77       Yes     Artist              0.0
# 3  461646  Female          Yes   60       Yes     Artist              NaN
# 4  459591    Male          Yes   50       Yes     Artist              1.0
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0           High          2.0  Cat_6            B
# 1           High          2.0  Cat_6            C
# 2           High          2.0  Cat_6            B
# 3           High          4.0  Cat_6            C
# 4        Average          3.0  Cat_6            C

# %% [markdown]
# infoメソッドやdescribeメソッドを使って、おかしなデータがないか確認する。

# %%
#データの欠損と型の確認(info)
df.info()

#gender, age, spendingscore, segmentation以外に欠損があるが、そこまで欠損が多いわけではないので欠損は無視して分析すれば問題ない
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               6454 non-null   int64
#  1   Gender           6454 non-null   object
#  2   Ever_Married     6338 non-null   object
#  3   Age              6454 non-null   int64
#  4   Graduated        6396 non-null   object
#  5   Profession       6355 non-null   object
#  6   Work_Experience  5781 non-null   float64
#  7   Spending_Score   6454 non-null   object
#  8   Family_Size      6190 non-null   float64
#  9   Var_1            6392 non-null   object
#  10  Segmentation     6454 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 554.8+ KB

# %%
#データ要約確認(describe)
display(df.describe()) #数値データ
display(df.describe(include="object")) #文字列データ

#Work_Experienceの最大が14なのは少し気になるが、概ね問題なし
# Out:
#                   ID          Age  Work_Experience  Family_Size
# count    6454.000000  6454.000000      5781.000000  6190.000000
# mean   463493.070964    43.235203         2.604048     2.862036
# std      2583.148482    16.693985         3.362028     1.529702
# min    458982.000000    18.000000         0.000000     1.000000
# 25%    461285.250000    30.000000         0.000000     2.000000
# 50%    463506.500000    40.000000         1.000000     3.000000
# 75%    465735.750000    53.000000         4.000000     4.000000
# max    467974.000000    89.000000        14.000000     9.000000
#        Gender Ever_Married Graduated Profession Spending_Score  Var_1  \
# count    6454         6338      6396       6355           6454   6392
# unique      2            2         2          9              3      7
# top      Male          Yes       Yes     Artist            Low  Cat_6
# freq     3563         3690      3960       1980           3886   4211
#
#        Segmentation
# count          6454
# unique            4
# top               D
# freq           1843

# %% [markdown]
# ## 課題1. 各セグメンテーションの人数と構成比率はどれくらいか？

# %% [markdown]
# セグメンテーション毎の顧客数の確認する
# セグメンテーション毎の顧客数の構成比率の算出する

# %%
#各セグメンテーションの人数を棒グラフで確認
sns.countplot(x="Segmentation", data=df, palette="Blues", order=["A", "B", "C", "D"])

#Dがやや多いが、人数はほぼ均等
# Out:
# <Axes: xlabel='Segmentation', ylabel='count'>

# %%
#セグメンテーション別の顧客数と構成比率を算出
df_segment_rate = df.groupby("Segmentation", as_index=False).count()[["Segmentation", "ID"]] #契約数
df_segment_rate.columns = ["Segmentation", "segment_count"] #列名変更
df_segment_rate["segment_rate"] = df_segment_rate["segment_count"] / df["ID"].count() #構成比率
df_segment_rate
# Out:
#   Segmentation  segment_count  segment_rate
# 0            A           1571      0.243415
# 1            B           1480      0.229315
# 2            C           1560      0.241711
# 3            D           1843      0.285559

# %% [markdown]
# ### 【結論】各セグメンテーションの人数と構成比率
# - Dが少し多いがほぼ均等
# - D,A,C,Bの順に人数が多い
# - 各セグメントの人数は約1500~1800人、構成比率は23~28%
# - 詳細は上記集計表参照

# %% [markdown]
# ## 課題2. 各セグメンテーションの顧客はどのような顧客なのか？

# %% [markdown]
# Gender,Ever_Married,Age,Graduated,Profession,Work_Experience,Spending_Score,Family_Size,Var_1と定期預金契約との関係性を確認する
# →連続変数はセグメント毎に上記の変数の箱ひげ図orバイオリンプロットを作成する + 統計値(平均など)の差を確認する
# →カテゴリー変数はセグメント×カテゴリーで人数や比率を棒グラフや集計値で確認する

# %%
#Gender
target = "Gender"
sns.countplot(x="Segmentation", hue=target, data=df, palette="Blues", order=["A", "B", "C", "D"])
df_rate = df.groupby(["Segmentation", target], as_index=False).count()[["Segmentation", target, "ID"]]
df_rate.columns = ["Segmentation", target, "count"] #セグメント×性別ごとの人数を算出
df_rate = pd.merge(df_rate, df_segment_rate, on="Segmentation", how="left") #セグメントの合計人数をjoin
df_rate["rate"] = df_rate["count"] / df_rate["segment_count"] #セグメント内の男女比率を算出
df_rate[["Segmentation", target, "count", "rate"]]

#Dだけ男性比率が58%とやや高い傾向があるが、ほぼ差はない
# Out:
#   Segmentation  Gender  count      rate
# 0            A  Female    723  0.460216
# 1            A    Male    848  0.539784
# 2            B  Female    682  0.460811
# 3            B    Male    798  0.539189
# 4            C  Female    713  0.457051
# 5            C    Male    847  0.542949
# 6            D  Female    773  0.419425
# 7            D    Male   1070  0.580575

# %%
#Ever_Married
target = "Ever_Married"
sns.countplot(x="Segmentation", hue=target, data=df, palette="Blues", order=["A", "B", "C", "D"])
df_rate = df.groupby(["Segmentation", target], as_index=False).count()[["Segmentation", target, "ID"]]
df_rate.columns = ["Segmentation", target, "count"] #セグメント×性別ごとの人数を算出
df_rate = pd.merge(df_rate, df_segment_rate, on="Segmentation", how="left") #セグメントの合計人数をjoin
df_rate["rate"] = df_rate["count"] / df_rate["segment_count"] #セグメント内の男女比率を算出
df_rate[["Segmentation", target, "count", "rate"]]

#Dは未婚率が非常に高い
#反対にB,Cは既婚率が高い
#Aはそれらの中間くらいで、既婚者の方がやや多い
# Out:
#   Segmentation Ever_Married  count      rate
# 0            A           No    640  0.407384
# 1            A          Yes    902  0.574157
# 2            B           No    382  0.258108
# 3            B          Yes   1071  0.723649
# 4            C           No    315  0.201923
# 5            C          Yes   1224  0.784615
# 6            D           No   1311  0.711340
# 7            D          Yes    493  0.267499

# %%
#Age
target = "Age"
sns.violinplot(x="Segmentation", y=target, data=df, palette="Blues", order=["A", "B", "C", "D"]) #バイオリンプロット
df.groupby("Segmentation").describe()[target]

#Dは年齢が比較的若く、半分以上が20代以下
#B,Cは40代後半を中心に正規分布に近い形で分布
#Aはそれらの中間で、30~40代に集中
# Out:
#                count       mean        std   min   25%   50%   75%   max
# Segmentation
# A             1571.0  44.717377  16.322048  18.0  32.5  41.0  52.0  89.0
# B             1480.0  47.979730  14.758717  18.0  37.0  46.0  58.0  89.0
# C             1560.0  49.087821  14.493567  18.0  38.0  49.0  58.0  89.0
# D             1843.0  33.207813  15.716016  18.0  22.0  29.0  37.0  89.0

# %%
#Graduated
target = "Graduated"
sns.countplot(x="Segmentation", hue=target, data=df, palette="Blues", order=["A", "B", "C", "D"])
df_rate = df.groupby(["Segmentation", target], as_index=False).count()[["Segmentation", target, "ID"]]
df_rate.columns = ["Segmentation", target, "count"] #セグメント×性別ごとの人数を算出
df_rate = pd.merge(df_rate, df_segment_rate, on="Segmentation", how="left") #セグメントの合計人数をjoin
df_rate["rate"] = df_rate["count"] / df_rate["segment_count"] #セグメント内の男女比率を算出
df_rate[["Segmentation", target, "count", "rate"]]

#C>B>A>Dの順に大卒率が高い
#特にDは大卒の方が少なく、他と対照的
# Out:
#   Segmentation Graduated  count      rate
# 0            A        No    587  0.373647
# 1            A       Yes    967  0.615532
# 2            B        No    408  0.275676
# 3            B       Yes   1057  0.714189
# 4            C        No    276  0.176923
# 5            C       Yes   1272  0.815385
# 6            D        No   1165  0.632122
# 7            D       Yes    664  0.360282

# %%
#Profession
target = "Profession"
sns.countplot(x="Segmentation", hue=target, data=df, palette="Blues", order=["A", "B", "C", "D"])
df_rate = df.groupby(["Segmentation", target], as_index=False).count()[["Segmentation", target, "ID"]]
df_rate.columns = ["Segmentation", target, "count"] #セグメント×性別ごとの人数を算出
df_rate = pd.merge(df_rate, df_segment_rate, on="Segmentation", how="left") #セグメントの合計人数をjoin
df_rate["rate"] = df_rate["count"] / df_rate["segment_count"] #セグメント内の男女比率を算出
df_rate[["Segmentation", target, "count", "rate"]]

#Dの43%はHealthcareで、他と比べて圧倒的に多い
#Cは半分以上(54%)がArtistで他はそれぞれ10%以下
#AとBは似ており、Artist>Entertainment>Engineerの順に多い(Bの方がややArtistに偏っている)
# Out:
#    Segmentation     Profession  count      rate
# 0             A         Artist    432  0.274984
# 1             A         Doctor    155  0.098663
# 2             A       Engineer    203  0.129217
# 3             A  Entertainment    297  0.189052
# 4             A      Executive    103  0.065563
# 5             A     Healthcare     84  0.053469
# 6             A      Homemaker     61  0.038829
# 7             A         Lawyer    161  0.102482
# 8             A      Marketing     48  0.030554
# 9             B         Artist    595  0.402027
# 10            B         Doctor    111  0.075000
# 11            B       Engineer    151  0.102027
# 12            B  Entertainment    184  0.124324
# 13            B      Executive    152  0.102703
# 14            B     Healthcare     85  0.057432
# 15            B      Homemaker     45  0.030405
# 16            B         Lawyer    119  0.080405
# 17            B      Marketing     20  0.013514
# 18            C         Artist    845  0.541667
# 19            C         Doctor    111  0.071154
# 20            C       Engineer     61  0.039103
# 21            C  Entertainment    114  0.073077
# 22            C      Executive    149  0.095513
# 23            C     Healthcare    109  0.069872
# 24            C      Homemaker     17  0.010897
# 25            C         Lawyer    106  0.067949
# 26            C      Marketing     33  0.021154
# 27            D         Artist    108  0.058600
# 28            D         Doctor    170  0.092241
# 29            D       Engineer    145  0.078676
# 30            D  Entertainment    173  0.093869
# 31            D      Executive     96  0.052089
# 32            D     Healthcare    804  0.436245
# 33            D      Homemaker     74  0.040152
# 34            D         Lawyer    105  0.056972
# 35            D      Marketing    129  0.069995

# %%
#Work_Experience
target = "Work_Experience"
sns.violinplot(x="Segmentation", y=target, data=df, palette="Blues", order=["A", "B", "C", "D"]) #バイオリンプロット
df.groupby("Segmentation").describe()[target]

#中央値をみると、全てのセグメントで半分以上が0~1に偏っている
#平均値とグラフをみると、AとDは8~10にややボリュームがあり、平均職務歴が長い印象
#ただ、セグメントでWork_Experienceにほとんど差はないと言ってもよい印象
# Out:
#                count      mean       std  min  25%  50%  75%   max
# Segmentation
# A             1417.0  2.812985  3.561153  0.0  0.0  1.0  5.0  14.0
# B             1322.0  2.358548  3.192066  0.0  0.0  1.0  3.0  14.0
# C             1434.0  2.165272  2.943505  0.0  0.0  1.0  3.0  14.0
# D             1608.0  3.013060  3.598790  0.0  0.0  1.0  6.0  14.0

# %%
#Spending_Score
target = "Spending_Score"
sns.countplot(x="Segmentation", hue=target, data=df, palette="Blues", order=["A", "B", "C", "D"])
df_rate = df.groupby(["Segmentation", target], as_index=False).count()[["Segmentation", target, "ID"]]
df_rate.columns = ["Segmentation", target, "count"] #セグメント×性別ごとの人数を算出
df_rate = pd.merge(df_rate, df_segment_rate, on="Segmentation", how="left") #セグメントの合計人数をjoin
df_rate["rate"] = df_rate["count"] / df_rate["segment_count"] #セグメント内の男女比率を算出
df_rate[["Segmentation", target, "count", "rate"]]

#DはLowが87%もあり、支出が少ない顧客が集中している
#Cは反対にAverageが多く、セグメントの中では顧客の支出が多そう
#全体にC>B>A>Dの順に支出が多い顧客が多い
# Out:
#    Segmentation Spending_Score  count      rate
# 0             A        Average    280  0.178230
# 1             A           High    222  0.141311
# 2             A            Low   1069  0.680458
# 3             B        Average    488  0.329730
# 4             B           High    307  0.207432
# 5             B            Low    685  0.462838
# 6             C        Average    716  0.458974
# 7             C           High    325  0.208333
# 8             C            Low    519  0.332692
# 9             D        Average    103  0.055887
# 10            D           High    127  0.068909
# 11            D            Low   1613  0.875203

# %%
#Family_Size
target = "Family_Size"
sns.violinplot(x="Segmentation", y=target, data=df, palette="Blues", order=["A", "B", "C", "D"]) #バイオリンプロット
df.groupby("Segmentation").describe()[target]

#中央値をみると、どのセグメントも半分以上が2~3人以下の家族
#グラフをみると、Dだけ1~5人まで幅広く分布しており、Aは1~2人に特に集中している
#Dは若く未婚の人が多いため、実家暮らしの人が多いのかもしれない
# Out:
#                count      mean       std  min  25%  50%  75%  max
# Segmentation
# A             1498.0  2.440587  1.484098  1.0  1.0  2.0  3.0  9.0
# B             1445.0  2.723183  1.418925  1.0  2.0  2.0  4.0  9.0
# C             1524.0  2.998688  1.373704  1.0  2.0  3.0  4.0  9.0
# D             1723.0  3.224028  1.679197  1.0  2.0  3.0  4.0  9.0

# %%
#Var_1
target = "Var_1"
sns.countplot(x="Segmentation", hue=target, data=df, palette="Blues", order=["A", "B", "C", "D"])
df_rate = df.groupby(["Segmentation", target], as_index=False).count()[["Segmentation", target, "ID"]]
df_rate.columns = ["Segmentation", target, "count"] #セグメント×性別ごとの人数を算出
df_rate = pd.merge(df_rate, df_segment_rate, on="Segmentation", how="left") #セグメントの合計人数をjoin
df_rate["rate"] = df_rate["count"] / df_rate["segment_count"] #セグメント内の男女比率を算出
df_rate[["Segmentation", target, "count", "rate"]]

#セグメント間でそこまで大きな差があるようには見えない
#カテゴリー分けの基準も不明なため、このデータはあまり使えなさそう
# Out:
#    Segmentation  Var_1  count      rate
# 0             A  Cat_1     26  0.016550
# 1             A  Cat_2     64  0.040738
# 2             A  Cat_3    165  0.105029
# 3             A  Cat_4    256  0.162954
# 4             A  Cat_5     15  0.009548
# 5             A  Cat_6    989  0.629535
# 6             A  Cat_7     39  0.024825
# 7             B  Cat_1     23  0.015541
# 8             B  Cat_2     81  0.054730
# 9             B  Cat_3    155  0.104730
# 10            B  Cat_4    187  0.126351
# 11            B  Cat_5     15  0.010135
# 12            B  Cat_6    976  0.659459
# 13            B  Cat_7     31  0.020946
# 14            C  Cat_1     22  0.014103
# 15            C  Cat_2     82  0.052564
# 16            C  Cat_3    124  0.079487
# 17            C  Cat_4     85  0.054487
# 18            C  Cat_5     17  0.010897
# 19            C  Cat_6   1176  0.753846
# 20            C  Cat_7     37  0.023718
# 21            D  Cat_1     42  0.022789
# 22            D  Cat_2    104  0.056430
# 23            D  Cat_3    197  0.106891
# 24            D  Cat_4    338  0.183397
# 25            D  Cat_5     23  0.012480
# 26            D  Cat_6   1070  0.580575
# 27            D  Cat_7     53  0.028757

# %% [markdown]
# ### 【結論】各セグメントの特徴
# 大まかな感じだと各セグメントの距離関係は、D----A--B-Cのような感じになっている印象で、Dが他とかけ離れているのが一番の特徴
# 各セグメントの特徴は以下
#
# - A：30~40代、大卒、Artist、一人or二人暮らし
# - B：既婚、40~50代、大卒、Artist
# - C：既婚、40~50代、大卒、Artist、支出が比較的多い
# - D：未婚、20代、学歴は低め、Healthcare関連の職種、支出が少ない、実家暮らし

# %% [markdown]
# ## 課題3. マーケティング部が設定しているセグメンテーションは適切か？他によりよいセグメント基準がありそうか？

# %% [markdown]
# この課題はデータ分析の結果をビジネスに活かす力をつけるための練習課題です。
# まずは、このセグメントがビジネスに使えるとしたら、どんなパターンがありそうか、自由に考えてみましょう。
# つぎに、このセグメントの問題点を考えてみましょう。
# 最後に、もっとマーケティング部に役立ちそうなセグメントを作るとしたら、どんなセグメントがありそうか考えてみましょう。

# %% [markdown]
# #### このセグメントが活用できるパターン
# - Dの特徴を持つ人に特別実施したいプロモーションがある
#   (Healthcare関連で若めの人に役立つ課題があるor低学歴でもOKなどといった打ち出しをしたいなど)
#
# #### このセグメントの問題点
# - D以外のセグメントがほぼ同じ特徴であり、セグメントを分ける必要性が薄い
#
# #### 他により良いセグメント基準がありそうか
# - ベーシックプランとプレミアムプランで出し分けてプロモーションをするならSpending_score×学歴×年齢の組み合わせで経済力別のセグメントを作る
# - 通常プランとビジネスプラン(for Biz)で出し分けるなら職業(Executiveか否か)×年齢の組み合わせで社内地位別のセグメントを作る
# - ペルソナベースでユーザーの心理をつくプロモーションをしていくなら、年齢×性別の組み合わせでデモグラ別のセグメントを作る
# - 結局のところ、マーケティング部がどのようなプロモーションを考えるかによって適切なセグメントも変わるため、実務なら上記の分析結果をもとにマーケティング部に入念なヒアリングを行うのもあり

# %% [markdown]
# ## 分析の結論

# %% [markdown]
# 課題1.各セグメンテーションの人数と構成比率
# - Dが少し多いがほぼ均等
# - D,A,C,Bの順に人数が多い
# - 各セグメントの人数は約1500~1800人、構成比率は23~28%
# - 詳細は下記集計表参照

# %%
df_segment_rate
# Out:
#   Segmentation  segment_count  segment_rate
# 0            A           1571      0.243415
# 1            B           1480      0.229315
# 2            C           1560      0.241711
# 3            D           1843      0.285559

# %% [markdown]
# 課題2.各セグメントの特徴
# 大まかな感じだと各セグメントの距離関係は、D----A--B-Cのような感じになっている印象で、Dが他とかけ離れているのが一番の特徴
# 各セグメントの特徴は以下
# - A：30~40代、大卒、Artist、一人or二人暮らし
# - B：既婚、40~50代、大卒、Artist
# - C：既婚、40~50代、大卒、Artist、支出が比較的多い
# - D：未婚、20代、学歴は低め、Healthcare関連の職種、支出が少ない、実家暮らし

# %% [markdown]
# 課題3.このセグメントは適切か？
#
# このセグメントが活用できるパターン
# - Dの特徴を持つ人に特別実施したいプロモーションがある
#   (Healthcare関連で若めの人に役立つ課題があるor低学歴でもOKなどといった打ち出しをしたいなど)
#
# このセグメントの問題点
# - D以外のセグメントがほぼ同じ特徴であり、セグメントを分ける必要性が薄い
#
# 他により良いセグメント基準がありそうか
# - ベーシックプランとプレミアムプランで出し分けてプロモーションをするならSpending_score×学歴×年齢の組み合わせで経済力別のセグメントを作る
# - 通常プランとビジネスプラン(for Biz)で出し分けるなら職業(Executiveか否か)×年齢の組み合わせで社内地位別のセグメントを作る
# - ペルソナベースでユーザーの心理をつくプロモーションをしていくなら、年齢×性別の組み合わせでデモグラ別のセグメントを作る
# - 結局のところ、マーケティング部がどのようなプロモーションを考えるかによって適切なセグメントも変わるため、実務なら上記の分析結果をもとにマーケティング部に入念なヒアリングを行うのもあり
